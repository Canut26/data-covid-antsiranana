# %% [markdown]
# # 04 — Modélisation Prédictive
#
# **Prédiction de mortalité COVID-19 — Antsiranana**

# %%
import sys
sys.path.insert(0, "../scripts")
from predictive_model import run_full_pipeline
import matplotlib.pyplot as plt
from IPython.display import Image

results = run_full_pipeline()

# %% [markdown]
# ## Courbes ROC

# %%
Image("../figures/08_roc_curves.png", width=600)

# %% [markdown]
# ## Importance des variables (Random Forest)

# %%
Image("../figures/09_feature_importance.png", width=700)

# %% [markdown]
# ## Résultats
#
# | Modèle | AUC-ROC | Accuracy |
# |---|---|---|
# | Régression Logistique | ~0.76 | ~0.79 |
# | **Random Forest** | **~0.83** | **~0.84** |
#
# **Variables les plus prédictives :** Sévérité (ordinal), qSOFA, CRP, NLR, Créatinine, Âge
